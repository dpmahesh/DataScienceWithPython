# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
h1 = pd.read_csv('../data/h1.csv')
h1
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 40055           0       212             2017           August
# 40056           0       169             2017           August
# 40057           0       204             2017           August
# 40058           0       211             2017           August
# 40059           0       161             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
h1.columns
# Out:
# Index(['IsCanceled', 'LeadTime', 'ArrivalDateYear', 'ArrivalDateMonth',
#        'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
h2 = pd.read_csv('../data/h2.csv')
h2
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0         6             2015             July
# 1               1        88             2015             July
# 2               1        65             2015             July
# 3               1        92             2015             July
# 4               1       100             2015             July
# ...           ...       ...              ...              ...
# 79325           0        23             2017           August
# 79326           0       102             2017           August
# 79327           0        34             2017           August
# 79328           0       109             2017           August
# 79329           0       205             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
h2.columns
# Out:
# Index(['IsCanceled', 'LeadTime', 'ArrivalDateYear', 'ArrivalDateMonth',
#        'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
h_df = pd.concat([h1,h2])
h_df
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 79325           0        23             2017           August
# 79326           0       102             2017           August
# 79327           0        34             2017           August
# 79328           0       109             2017           August
# 79329           0       205             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
h_df.describe()
# Out:
#           IsCanceled       LeadTime  ArrivalDateYear  ArrivalDateWeekNumber  \
# count  119390.000000  119390.000000    119390.000000          119390.000000
# mean        0.370416     104.011416      2016.156554              27.165173
# std         0.482918     106.863097         0.707476              13.605138
# min         0.000000       0.000000      2015.000000               1.000000
# 25%         0.000000      18.000000      2016.000000              16.000000
# 50%         0.000000      69.000000      2016.000000              28.000000
# 75%         1.000000     160.000000      2017.000000              38.000000
# max         1.000000     737.000000      2017.000000              53.000000
#
#        ArrivalDateDayOfMonth  StaysInWeekendNights  StaysInWeekNights  \
# count          119390.000000         119390.000000      119390.000000
# mean               15.798241              0.927599           2.500302
# std                 8.780829              0.998613           1.908286
# ...

# %%
h_df.info
# Out:
# <bound method DataFrame.info of        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 79325           0        23             2017           August
# 79326           0       102             2017           August
# 79327           0        34             2017           August
# 79328           0       109             2017           August
# 79329           0       205             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
h_df.ArrivalDateYear.max()
# Out:
# 2017

# %%
h_df.ArrivalDateYear.min()
# Out:
# 2015

# %%
sns.lineplot(data=h_df,x='ArrivalDateYear',y='IsRepeatedGuest')
# Out:
# <AxesSubplot:xlabel='ArrivalDateYear', ylabel='IsRepeatedGuest'>

# %%
h_df.hist(bins=10,figsize=(10,20))
plt.show()
